# %% [markdown]
# <a href="https://colab.research.google.com/github/wooram10802/10802/blob/main/20260904%EC%9E%85%EB%A0%A5%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = input('이름')
b = input('나이:')
print(a, '님 안녕하세요')
print(20-int(b), '년 후면 20살이시네요!')
# Out:
# 이름20
# 나이:18
# 20 님 안녕하세요
# 2 년 후면 20살이시네요!

# %%
print(7/3)
print(7//3)
print(7%3)
# Out:
# 2.3333333333333335
# 2
# 1

# %%
sec = int(input('시간을 초 단위로 입력하세요:'))
minutes = sec // 60
seconds = sec % 60
print(f'{minutes}분 {seconds}초')
# Out:
# 시간을 초 단위로 입력하세요:1200
# 20분 0초

# %%
학번 = int(input('학번을 입력하하세요'))
성명 = input('성명을 입력하세요')
소속 = input('소속을 입력하세요')
print('##########################################')

print('[한양과학기술고등학교 학생증]')
print(f'*{학번}')
print(f'*{성명}')
print(f'*{소속}')
print('위 사람은 본 학교의 학생임을 증명함')

print('############################################')
# Out:
# 학번을 입력하하세요10802
# 성명을 입력하세요곽우람
# 소속을 입력하세요전자과
# ##########################################
# [한양과학기술고등학교 학생증]
# *10802
# *곽우람
# *전자과
# 위 사람은 본 학교의 학생임을 증명함
# ############################################
