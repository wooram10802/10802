# %% [markdown]
# <a href="https://colab.research.google.com/github/wooram10802/10802/blob/main/20260902%EC%B6%9C%EB%A0%A5%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("안녕하세요")
print(3+7)
print('3+7')
# Out:
# 안녕하세요
# 10
# 3+7

# %%
print('한양과학기술고등학교', '1학년', '곽우람')
print('체질량 지수(BMI)', 90/(180 * 180) * 10000)
# Out:
# 한양과학기술고등학교 1학년 곽우람
# 체질량 지수(BMI) 27.77777777777778

# %%
c = 90
d = 3.141592
print(f'직각은 {c}도, 원주율은 {d:0.2f}입니다')
# Out:
# 직각은 90도, 원주율은 3.14입니다

# %%
print('동해 물과 \'백두산\'이')
print('마르고 닳도록')
print('하느님이 보우우하사 ￦n우리나라 만세')
print('무궁화 삼천리', end = '')
print('대한 사람, "대한"으로 길이 보전하세.')
print('2026', '05', '20', sep='-')
# Out:
# 동해 물과 '백두산'이
# 마르고 닳도록
# 하느님이 보우우하사 ￦n우리나라 만세
# 무궁화 삼천리대한 사람, "대한"으로 길이 보전하세.
# 2026-05-20

# %%
print('#############################')
print('[한양과학기술고등학교 학생증]')
print('* 학번: 10802')
print('* 성명: 곽우람')
print('* 소속: 스마트전자과')
print('위 사람은 본 학교의 학생임을 증명함')
print('##############################')
# Out:
# #############################
# [한양과학기술고등학교 학생증]
# * 학번: 10802
# * 성명: 곽우람
# * 소속: 스마트전자과
# 위 사람은 본 학교의 학생임을 증명함
# ##############################
