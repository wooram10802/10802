# %% [markdown]
# <a href="https://colab.research.google.com/github/wooram10802/10802/blob/main/20260907.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime, date, time

# %%
print('<디디데이 (D-day) 프로그램')
print()
year =int(input('연도를 입력하세요: '))
month = int(input('월을 입력하세요:'))
day = int(input('일을 입입력하세요:'))
dt4 = date(year, month, day)
today = date.today()
dday = (dt4 - today).days
print(f'{year}년 {month}월월 {day}일은 {dday}일 남았습니다.')
# Out:
# <디디데이 (D-day) 프로그램
#
# 연도를 입력하세요: 2026
# 월을 입력하세요:9
# 일을 입입력하세요:7
# 2026년 9월월 7일은 0일 남았습니다.

# %%
print('=====회전 초밥 영수증=====')
print('접시, 단가, 개수, 합계')
a = int(input('빨간색 갯수를 입력하세요'))
a2 = 1000
print(f'빨간색 {a2}  {a}, {1000 * a}')
b = int(input('노란색 갯수를 입력하세요'))
b2 = 2000
print(f'노란색 {b2}  {b}, {2000 * b}')
c = int(input('파란색 갯수를 입력하세요'))
c2 = 3000
print(f'파란색 {c2}  {c}, {3000 * c}')
d = int(input('초록색 갯수를 입력하세요'))
d2 = 4000
print(f'초록색 {d2}  {d}, {4000 * d}')
print(f'총가격 {1000 * a + 2000 * b + 3000 * c + 4000 * d}')
# Out:
# =====회전 초밥 영수증=====
# 접시, 단가, 개수, 합계
# 빨간색 갯수를 입력하세요2
# 빨간색 1000  2, 2000
# 노란색 갯수를 입력하세요3
# 노란색 2000  3, 6000
# 파란색 갯수를 입력하세요1
# 파란색 3000  1, 3000
# 초록색 갯수를 입력하세요2
# 초록색 4000  2, 8000
# 총가격 19000

# %%
print('=====회전 초밥 영수증=====')
a = int(input('빨간색 갯수를 입력하세요'))
a2 = 1000
print(f'빨간색 {a2}  {a}, {1000 * a}')
